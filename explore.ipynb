# %%
import spikeinterface.extractors as se
import spikeinterface.widgets as sw
recording_path = '/home/sheppardj@hhmi.org/Documents/ephys-pipeline/data/output/probe_a/shank_2.0/raw_recording/traces_cached_seg0.raw'
recording = se.read_binary(recording_path, sampling_frequency=30000, dtype='int32', num_channels=96)
print(recording.get_total_duration())
sw.plot_traces(recording=recording, channel_ids=[0], time_range=[0,20])
# Out:
# 120.0

# %%
recording_path = '/home/sheppardj@hhmi.org/Documents/ephys-pipeline/data/output/probe_a/shank_2.0/recording/traces_cached_seg0.raw'
recording = se.read_binary(recording_path, sampling_frequency=30000, dtype='float32', num_channels=96)
print(recording.get_total_duration())
sw.plot_traces(recording=recording, channel_ids=[0], time_range=[0,20])
# Out:
# 120.0

# %%
recording_path = '/groups/voigts/voigtslab/neuropixels_tests_aug_2024/2024_09_06_npx_3dmaze/data/probe_a_2024-09-06T09_38_01.bin'
recording = se.read_binary(recording_path, sampling_frequency=30000, dtype='int32', num_channels=384)
snippet = recording.time_slice(0, 60)
print(snippet.get_total_duration())
sw.plot_traces(recording=snippet, channel_ids=[0], time_range=[0,20])
# Out:
# 60.0
